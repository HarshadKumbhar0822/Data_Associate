# %% [markdown]
# <a href="https://colab.research.google.com/github/HarshadKumbhar0822/Data_Associate/blob/main/Pandas_library.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pandas
import pandas as pd

# %%
df = pd.read_csv('demo.csv')
df
# Out:
#    id     name  adress qualification
# 0   1     yash    Pune           BCS
# 1   2  Harshad    Pune           MCA
# 2   3  Vitthal    Pune           BCS
# 3   4   Pankaj  Pashan            BE
# 4   5  Rushabh   Baner           MCA

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             5 non-null      int64
#  1   name           5 non-null      object
#  2   adress         5 non-null      object
#  3   qualification  5 non-null      object
# dtypes: int64(1), object(3)
# memory usage: 288.0+ bytes

# %%
df.describe(include='all')
# Out:
#               id  name adress qualification
# count   5.000000     5      5             5
# unique       NaN     5      3             3
# top          NaN  yash   Pune           BCS
# freq         NaN     1      3             2
# mean    3.000000   NaN    NaN           NaN
# std     1.581139   NaN    NaN           NaN
# min     1.000000   NaN    NaN           NaN
# 25%     2.000000   NaN    NaN           NaN
# 50%     3.000000   NaN    NaN           NaN
# 75%     4.000000   NaN    NaN           NaN
# max     5.000000   NaN    NaN           NaN

# %%
df.nunique()
# Out:
# id               5
# name             5
# adress           3
# qualification    3
# dtype: int64

# %%
print(df.shape)
print(df.ndim)
print(df.size)
print(type(df))
# Out:
# (5, 4)
# 2
# 20
# <class 'pandas.core.frame.DataFrame'>

# %%
df.isnull().sum()
# Out:
# id               0
# name             0
# adress           0
# qualification    0
# dtype: int64

# %%
import numpy as np
df.replace(np.nan,0,inplace=True)
df
# Out:
#    id     name  adress qualification
# 0   1     yash    Pune           BCS
# 1   2  Harshad    Pune           MCA
# 2   3  Vitthal    Pune           BCS
# 3   4   Pankaj  Pashan            BE
# 4   5  Rushabh   Baner           MCA

# %%
df.loc[0] #to access perticular row
# Out:
# id                  1
# name             yash
# adress           Pune
# qualification     BCS
# Name: 0, dtype: object

# %%
df.loc[6] = [7,'Raju','Baner',np.nan]
df
# Out:
#    id     name  adress qualification
# 0   1     yash    Pune           BCS
# 1   2  Harshad    Pune           MCA
# 2   3  Vitthal    Pune           BCS
# 3   4   Pankaj  Pashan            BE
# 4   5  Rushabh   Baner           MCA
# 6   7     Raju   Baner           NaN

# %%
dct = {'id':[1,2,3,4,5,6,7],
       'Name':['Karan','Harshad','Pankaj','Vitthal','Rushabh','Ram','Charan'],
       'Age':[20,21,22,23,24,25,26],
       'Qualification':['Btech','MCA','BCA','BCA','MCA','BCS','MCA']}

df = pd.DataFrame(dct)
df
# Out:
#    id     Name  Age Qualification
# 0   1    Karan   20         Btech
# 1   2  Harshad   21           MCA
# 2   3   Pankaj   22           BCA
# 3   4  Vitthal   23           BCA
# 4   5  Rushabh   24           MCA
# 5   6      Ram   25           BCS
# 6   7   Charan   26           MCA

# %%
lst = ['a','b','c','d']
df2 = pd.DataFrame(lst, index = ['Harshad','Pankaj','Vithhal','Raju'],columns = ['c_1'])
df2
# Out:
#         c_1
# Harshad   a
# Pankaj    b
# Vithhal   c
# Raju      d

# %%
df
# Out:
#    id     Name  Age Qualification
# 0   1    Karan   20         Btech
# 1   2  Harshad   21           MCA
# 2   3   Pankaj   22           BCA
# 3   4  Vitthal   23           BCA
# 4   5  Rushabh   24           MCA
# 5   6      Ram   25           BCS
# 6   7   Charan   26           MCA

# %%
df.loc[1:2,['Name','Qualification']]
# Out:
#       Name Qualification
# 1  Harshad           MCA
# 2   Pankaj           BCA

# %%
df.iloc[::2,::2]
# Out:
#    id  Age
# 0   1   20
# 2   3   22
# 4   5   24
# 6   7   26

# %%
df.loc[df['Name']== 'Harshad']
# Out:
#    id     Name  Age Qualification
# 1   2  Harshad   21           MCA

# %%
df = pd.DataFrame(
    {
        "Name": ['Harshad','Pankaj','Vithhal'],
        "Age": [22, 35, 58],
        "Sex": ["male", "male", "female"]    }
)
df.to_csv('demo1.csv')
df
# Out:
#       Name  Age     Sex
# 0  Harshad   22    male
# 1   Pankaj   35    male
# 2  Vithhal   58  female

# %%
adult_names = df.loc[df['Age'] > 30, 'Name']
adult_names
# Out:
# 1     Pankaj
# 2    Vithhal
# Name: Name, dtype: object

# %%
df.iloc[0:2, 2] = 'other'
df
# Out:
#       Name  Age     Sex
# 0  Harshad   22   other
# 1   Pankaj   35   other
# 2  Vithhal   58  female

# %%
df.drop(0,inplace=True)
df
# Out:
#       Name  Age     Sex
# 1   Pankaj   35   other
# 2  Vithhal   58  female

# %%
df.drop(['Age'], axis = 1, inplace = True)
df
df
# Out:
#       Name     Sex
# 2  Vithhal  female

# %%
dct = {'id':[1,2,3,4,5,6,7],
       'Name':['Karan','Harshad','Pankaj','Vitthal','Rushabh','Ram','Charan'],
       'Age':[20,21,22,23,24,25,26],
       'Qualification':['Btech','MCA','BCA','BCA','MCA','BCS','MCA']}

df = pd.DataFrame(dct)
df
# Out:
#    id     Name  Age Qualification
# 0   1    Karan   20         Btech
# 1   2  Harshad   21           MCA
# 2   3   Pankaj   22           BCA
# 3   4  Vitthal   23           BCA
# 4   5  Rushabh   24           MCA
# 5   6      Ram   25           BCS
# 6   7   Charan   26           MCA

# %%
df['new_col']= df['Name'].str.split('h').str.get(1)
df
# Out:
#    id     Name  Age Qualification new_col
# 0   1    Karan   20         Btech     NaN
# 1   2  Harshad   21           MCA      ad
# 2   3   Pankaj   22           BCA     NaN
# 3   4  Vitthal   23           BCA      al
# 4   5  Rushabh   24           MCA      ab
# 5   6      Ram   25           BCS     NaN
# 6   7   Charan   26           MCA    aran
