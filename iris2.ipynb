# %% [markdown]
# <a href="https://colab.research.google.com/github/HarshadKumbhar0822/Data_Associate/blob/main/iris2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
data = pd.read_csv('/content/Iris.csv')
data.head(20)
#Top 20 record
#NAN means not a number
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0    1.0            5.1           3.5            1.4           0.2
# 1    2.0            4.9           3.0            1.4           0.2
# 2    3.0            4.7           3.2            1.3           0.2
# 3    4.0            4.6           3.1            1.5           0.2
# 4    5.0            NaN           3.6            1.4           0.2
# 5    6.0            5.4           3.9            1.7           0.4
# 6    7.0            4.6           NaN            1.4           0.3
# 7    8.0            5.0           3.4            1.5           0.2
# 8    9.0            4.4           2.9            1.4           0.2
# 9   10.0            4.9           3.1            1.5           0.1
# 10  11.0            5.4           3.7            1.5           0.2
# 11  12.0            4.8           3.4            1.6           0.2
# 12  13.0            4.8           3.0            1.4           0.1
# ...

# %%
# 1.Missing Values i.e NAN
# 2.text type of data in species
# 3.Coloumn name should be short
data.tail(10)
# Out:
#         Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 140  141.0            6.7           3.1            5.6           2.4
# 141  142.0            6.9           3.1            5.1           2.3
# 142  143.0            5.8           2.7            5.1           1.9
# 143  144.0            6.8           3.2            5.9           2.3
# 144  145.0            6.7           3.3            5.7           2.5
# 145  146.0            6.7           3.0            5.2           2.3
# 146  147.0            6.3           2.5            NaN           1.9
# 147  148.0            NaN           3.0            5.2           2.0
# 148  149.0            6.2           3.4            5.4           2.3
# 149  150.0            5.9           3.0            5.1           1.8
#
#             Species
# 140  Iris-virginica
# 141  Iris-virginica
# 142  Iris-virginica
# 143             NaN
# 144  Iris-virginica
# 145  Iris-virginica
# 146  Iris-virginica
# 147  Iris-virginica
# ...

# %%
data.info()
# shows the information about data
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             148 non-null    float64
#  1   SepalLengthCm  146 non-null    float64
#  2   SepalWidthCm   148 non-null    float64
#  3   PetalLengthCm  147 non-null    float64
#  4   PetalWidthCm   149 non-null    float64
#  5   Species        145 non-null    object
# dtypes: float64(5), object(1)
# memory usage: 7.2+ KB

# %%
data.describe()
# Out:
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  148.000000     146.000000    148.000000     147.000000    149.000000
# mean    75.959459       5.844521      3.051351       3.781633      1.197315
# std     43.439046       0.833028      0.435576       1.758619      0.765555
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 25%     38.750000       5.100000      2.800000       1.600000      0.300000
# 50%     76.500000       5.800000      3.000000       4.400000      1.300000
# 75%    113.250000       6.400000      3.300000       5.100000      1.800000
# max    150.000000       7.900000      4.400000       6.900000      2.500000

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             148 non-null    float64
#  1   SepalLengthCm  146 non-null    float64
#  2   SepalWidthCm   148 non-null    float64
#  3   PetalLengthCm  147 non-null    float64
#  4   PetalWidthCm   149 non-null    float64
#  5   Species        145 non-null    object
# dtypes: float64(5), object(1)
# memory usage: 7.2+ KB

# %%
data["Species"].value_counts()
# Out:
# Species
# Iris-virginica     49
# Iris-setosa        48
# Iris-versicolor    48
# Name: count, dtype: int64

# %%
data.columns = ["Id", "sl", "sw", "pl", "pw", "species" ]
data.head()
# Out:
#     Id   sl   sw   pl   pw      species
# 0  1.0  5.1  3.5  1.4  0.2  Iris-setosa
# 1  2.0  4.9  3.0  1.4  0.2  Iris-setosa
# 2  3.0  4.7  3.2  1.3  0.2  Iris-setosa
# 3  4.0  4.6  3.1  1.5  0.2          NaN
# 4  5.0  NaN  3.6  1.4  0.2  Iris-setosa

# %%
data[['sl','sw']] #coloumn wise indexing
# Out:
#       sl   sw
# 0    5.1  3.5
# 1    4.9  3.0
# 2    4.7  3.2
# 3    4.6  3.1
# 4    NaN  3.6
# ..   ...  ...
# 145  6.7  3.0
# 146  6.3  2.5
# 147  NaN  3.0
# 148  6.2  3.4
# 149  5.9  3.0
#
# [150 rows x 2 columns]

# %%
data[50:101]
# Out:
#         Id   sl   sw   pl   pw          species
# 50    51.0  7.0  3.2  4.7  1.4  Iris-versicolor
# 51    52.0  6.4  3.2  4.5  1.5  Iris-versicolor
# 52    53.0  6.9  3.1  4.9  1.5  Iris-versicolor
# 53    54.0  5.5  2.3  4.0  1.3  Iris-versicolor
# 54    55.0  6.5  2.8  4.6  1.5  Iris-versicolor
# 55    56.0  5.7  2.8  4.5  1.3  Iris-versicolor
# 56    57.0  NaN  3.3  4.7  1.6  Iris-versicolor
# 57    58.0  4.9  2.4  3.3  1.0  Iris-versicolor
# 58    59.0  6.6  2.9  4.6  1.3  Iris-versicolor
# 59    60.0  5.2  2.7  3.9  1.4  Iris-versicolor
# 60    61.0  5.0  2.0  3.5  1.0  Iris-versicolor
# 61    62.0  5.9  3.0  4.2  1.5  Iris-versicolor
# 62    63.0  6.0  2.2  4.0  1.0  Iris-versicolor
# 63    64.0  6.1  2.9  4.7  1.4  Iris-versicolor
# 64    65.0  5.6  2.9  3.6  1.3  Iris-versicolor
# 65    66.0  6.7  3.1  4.4  NaN  Iris-versicolor
# 66    67.0  5.6  3.0  4.5  1.5  Iris-versicolor
# 67    68.0  5.8  2.7  4.1  1.0  Iris-versicolor
# 68     NaN  6.2  2.2  4.5  1.5  Iris-versicolor
# ...

# %%
data[-1:]
# Out:
#         Id   sl   sw   pl   pw         species
# 149  150.0  5.9  3.0  5.1  1.8  Iris-virginica

# %%
data.isna().sum()
# Out:
# Id         2
# sl         4
# sw         2
# pl         3
# pw         1
# species    5
# dtype: int64

# %%
data.dropna()
# Out:
#         Id   sl   sw   pl   pw         species
# 0      1.0  5.1  3.5  1.4  0.2     Iris-setosa
# 1      2.0  4.9  3.0  1.4  0.2     Iris-setosa
# 2      3.0  4.7  3.2  1.3  0.2     Iris-setosa
# 5      6.0  5.4  3.9  1.7  0.4     Iris-setosa
# 7      8.0  5.0  3.4  1.5  0.2     Iris-setosa
# ..     ...  ...  ...  ...  ...             ...
# 142  143.0  5.8  2.7  5.1  1.9  Iris-virginica
# 144  145.0  6.7  3.3  5.7  2.5  Iris-virginica
# 145  146.0  6.7  3.0  5.2  2.3  Iris-virginica
# 148  149.0  6.2  3.4  5.4  2.3  Iris-virginica
# 149  150.0  5.9  3.0  5.1  1.8  Iris-virginica
#
# [133 rows x 6 columns]

# %%
data["species"].fillna("Harshad")
# Out:
# 0         Iris-setosa
# 1         Iris-setosa
# 2         Iris-setosa
# 3             Harshad
# 4         Iris-setosa
#             ...
# 145    Iris-virginica
# 146    Iris-virginica
# 147    Iris-virginica
# 148    Iris-virginica
# 149    Iris-virginica
# Name: species, Length: 150, dtype: object

# %%
data.fillna(100)
# Out:
#         Id     sl   sw     pl   pw         species
# 0      1.0    5.1  3.5    1.4  0.2     Iris-setosa
# 1      2.0    4.9  3.0    1.4  0.2     Iris-setosa
# 2      3.0    4.7  3.2    1.3  0.2     Iris-setosa
# 3      4.0    4.6  3.1    1.5  0.2             100
# 4      5.0  100.0  3.6    1.4  0.2     Iris-setosa
# ..     ...    ...  ...    ...  ...             ...
# 145  146.0    6.7  3.0    5.2  2.3  Iris-virginica
# 146  147.0    6.3  2.5  100.0  1.9  Iris-virginica
# 147  148.0  100.0  3.0    5.2  2.0  Iris-virginica
# 148  149.0    6.2  3.4    5.4  2.3  Iris-virginica
# 149  150.0    5.9  3.0    5.1  1.8  Iris-virginica
#
# [150 rows x 6 columns]

# %%
#measure of center tendancy --> mean, median, mode to print the missing values

# %%
# numeric value can be filled with mean or median and text vallue filled with mode & Median.

# %%
# mean
me = data["sl"].mean()

# %%
data["sl"].mode()
# Out:
# 0    5.0
# 1    5.1
# Name: sl, dtype: float64

# %%
data["sl"].median()
# Out:
# 5.8

# %%
data["sl"].fillna(me,inplace=True)

# %%
# mean
me = data["sl"].mean()
# Out:
# 0      3.5
# 1      3.0
# 2      3.2
# 3      3.1
# 4      3.6
#       ...
# 145    3.0
# 146    2.5
# 147    3.0
# 148    3.4
# 149    3.0
# Name: sw, Length: 150, dtype: float64

# %%
# mean sw
me = data["sw"].mean()
data["sw"].mode()
data["sw"].fillna(me,inplace=True)
# Out:
# 0    3.0
# Name: sw, dtype: float64

# %%
#mean pw
me = data["pw"].mean()
data["pw"].mode()
data["pw"].fillna(me,inplace=True)

# %%
#mean pl
me = data["pl"].mean()
data["pl"].mode()
data["pl"].fillna(me,inplace=True)

# %%
data.isna().sum()
# Out:
# Id         2
# sl         0
# sw         0
# pl         0
# pw         0
# species    5
# dtype: int64

# %%
# mode
mo = data["species"].mode()
data["species"].mode()
data["species"].fillna("mo",inplace=True)

# %%
data.isna().sum()
# Out:
# Id         2
# sl         0
# sw         0
# pl         0
# pw         0
# species    0
# dtype: int64

# %%
data[50:101]
# Out:
#         Id        sl   sw   pl        pw          species
# 50    51.0  7.000000  3.2  4.7  1.400000  Iris-versicolor
# 51    52.0  6.400000  3.2  4.5  1.500000  Iris-versicolor
# 52    53.0  6.900000  3.1  4.9  1.500000  Iris-versicolor
# 53    54.0  5.500000  2.3  4.0  1.300000  Iris-versicolor
# 54    55.0  6.500000  2.8  4.6  1.500000  Iris-versicolor
# 55    56.0  5.700000  2.8  4.5  1.300000  Iris-versicolor
# 56    57.0  5.844521  3.3  4.7  1.600000  Iris-versicolor
# 57    58.0  4.900000  2.4  3.3  1.000000  Iris-versicolor
# 58    59.0  6.600000  2.9  4.6  1.300000  Iris-versicolor
# 59    60.0  5.200000  2.7  3.9  1.400000  Iris-versicolor
# 60    61.0  5.000000  2.0  3.5  1.000000  Iris-versicolor
# 61    62.0  5.900000  3.0  4.2  1.500000  Iris-versicolor
# 62    63.0  6.000000  2.2  4.0  1.000000  Iris-versicolor
# 63    64.0  6.100000  2.9  4.7  1.400000  Iris-versicolor
# 64    65.0  5.600000  2.9  3.6  1.300000  Iris-versicolor
# ...
